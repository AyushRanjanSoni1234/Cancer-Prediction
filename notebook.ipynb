# %%
import pandas as pd
import seaborn as sns

# %%
data1=pd.read_csv('/work/Breast_cancer_data.csv')

# %%
data1.columns
# Out:
# Index(['mean_radius', 'mean_texture', 'mean_perimeter', 'mean_area',
#        'mean_smoothness', 'diagnosis'],
#       dtype='object')

# %%
sns.relplot(x="mean_radius", y="mean_texture", size = "mean_area",hue='diagnosis', data = data1)

# %%
x=data1[['mean_radius','mean_texture','mean_perimeter','mean_area','mean_smoothness']]
y=data1['diagnosis']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier1 = LogisticRegression(random_state = 0,solver = 'saga',multi_class = 'ovr')
classifier1.fit(X_train, y_train)
# Out:
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# LogisticRegression(multi_class='ovr', random_state=0, solver='saga')

# %%
classifier1.score(X_test,y_test)
# Out:
# 0.9473684210526315
